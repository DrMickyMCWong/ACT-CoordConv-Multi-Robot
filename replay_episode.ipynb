# %%
import os
import h5py
import mediapy as media
import matplotlib.pyplot as plt

def load_hdf5(dataset_path):
    if not os.path.isfile(dataset_path):
        print(f'Dataset does not exist at \n{dataset_path}\n')
        exit()

    with h5py.File(dataset_path, 'r') as root:
        qpos = root['/observations/qpos'][()]
        qvel = root['/observations/qvel'][()]
        image_dict = dict()
        for cam_name in root[f'/observations/images/'].keys():
            image_dict[cam_name] = root[f'/observations/images/{cam_name}'][()]
        action = root['/action'][()]

    return qpos, qvel, action, image_dict

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/evaluation/task7c/eval_result_task7c_20251125_194553.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task2c\episode_9.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task1\eval_result_task1_20250824_203535.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task2c\eval_result_task2c_20250912_005927.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task3c\episode_0.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# plot action
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task5c\episode_5.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)

print(f"Dataset contains cameras: {list(image_dict.keys())}")

for cam_name, image_list in image_dict.items():
    print(f"\n📹 Camera: {cam_name}")
    print(f"   Shape: {image_list.shape}")
    print(f"   Frames: {len(image_list)}")
    
    # Show video with camera name in title
    media.show_video(image_list, fps=30, title=f"Camera: {cam_name}")

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# plot action
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task3c\eval_result_task3c_20250914_183648.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot action
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task4c\episode_5.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)

print(f"Dataset contains cameras: {list(image_dict.keys())}")

for cam_name, image_list in image_dict.items():
    print(f"\n📹 Camera: {cam_name}")
    print(f"   Shape: {image_list.shape}")
    print(f"   Frames: {len(image_list)}")
    
    # Show video with camera name in title
    media.show_video(image_list, fps=30, title=f"Camera: {cam_name}")

# %%
# plot action
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task4c\eval_result_task4c_20250915_203958.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task5C\eval_result_task5c_20250916_234909.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task6c\episode_45.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task6C\eval_result_task6c_20251008_230631.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task6c\eval_result_task6c_20251012_161642.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task6c\eval_result_task6c_20251012_163955.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task6c\episode_58.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task6c\eval_result_task6c_20251013_234103.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task6c\eval_result_task6c_20251014_000005.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task6c\episode_129.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\task7c\episode_65.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'C:\Users\Administrator\Documents\transformer\ACT-Shaka\data\evaluation\task7c\eval_result_task7c_20251019_233217.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/single_arm_pick_dataset/episode_60.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
# plot qpos
plt.figure()
plt.plot(qpos, label=list(range(1, 8)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 8)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# plot qpos
plt.figure()
plt.plot(action, label=list(range(1, 7)))
plt.xlabel('step')
plt.ylabel('angle [rad]')
plt.title('joint positions')
plt.legend()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/dataset_dir/real_episodes/episode_1.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/dataset_dir/sim_episodes/episode_1.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Sim Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/dataset_dir/real_episodes/episode_12.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/dataset_dir/real_episodes/episode_24.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/evaluation/task1/eval_result_task1_20260303_210805.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/dataset_dir/real_episodes/episode_15.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/ckpt_sim_pick_cube_teleop/eval_data/eval_rollout_3_20260220_110223.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/task1/episode_24.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/task1/episode_13.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/teleop_data/episode_22.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Real Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/ckpt_sim_pick_cube_teleop/eval_data/eval_rollout_0_20260220_170235.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Real Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Real Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/teleop_data/episode_0.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Real Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/ckpt_sim_pick_cube_teleop/eval_data/eval_rollout_0_20260220_213041.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title('Real Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/evaluation/task1/eval_result_task1_20260305_233202.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/dataset_dir/real_episodes/episode_49.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(action[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/evaluation/task1/eval_result_task1_20260323_124342.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/act-main/act/dataset_dir/sim_episodes/episode_9.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
data_file = r'/home/hk/Documents/ACT_Shaka/data/task1a/episode_0.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/evaluation/task1a/eval_result_task1a_20260322_215313.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)

# %%
plt.figure(figsize=(12, 8))
joint_names = ['Joint 1', 'Joint 2', 'Joint 3', 'Joint 4', 'Joint 5', 'Joint 6', 'Gripper']
for i in range(7):  # Changed from 6 to 7
    plt.plot(qpos[:, i], label=joint_names[i])
plt.xlabel('Timestep')
plt.ylabel('Value [rad] / [0-1]')
plt.title(' Joint Positions (7-DOF: 6 joints + gripper)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# play cam video
data_file = r'/home/hk/Documents/ACT_Shaka/data/evaluation/task1/eval_result_task1_20260325_124716.hdf5'
# data_file = 'data/demo/trained.hdf5'
qpos, qvel, action, image_dict = load_hdf5(dataset_path=data_file)
for cam_name, image_list in image_dict.items():
    media.show_video(image_list, fps=30)
